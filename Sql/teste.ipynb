# %%
# %load_ext sql
# %sql sqlite:///faculdade.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS alunos (
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     nome TEXT NOT NULL,
#     email TEXT
# );
# Out:
# Running query in 'sqlite:///faculdade.db'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# INSERT INTO alunos (nome, email)
# VALUES ('Nicolas', 'nicolas@email.com');
# Out:
# Running query in 'sqlite:///faculdade.db'
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT * FROM alunos;
# Out:
# Running query in 'sqlite:///faculdade.db'
# +----+---------+-------------------+
# | id |   nome  |       email       |
# +----+---------+-------------------+
# | 1  | Nicolas | nicolas@email.com |
# | 2  | Nicolas | nicolas@email.com |
# | 3  | Nicolas | nicolas@email.com |
# | 4  | Nicolas | nicolas@email.com |
# +----+---------+-------------------+
