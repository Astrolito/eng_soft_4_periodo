# %% [markdown]
# 6. Uma universidade deseja organizar informações das notas dos alunos."
#
# Pergunta: Quais são as entidades que podem ser
# representadas nesse cenário?

# %% [markdown]
# As principais entidades podem ser:
#
# - Aluno
# - Disciplina
# - Nota
# - Professor
# - Curso
# - Turma

# %% [markdown]
# 7. No mesmo contexto da universidade, os alunos realizam matrícula nos cursos.
#
# Pergunta: Qual relacionamento pode ser criado
# entre as entidades relacionadas?

# %% [markdown]
# relacionamento pode ser “Aluno realiza matrícula em Curso”.
#
# Esse relacionamento é muitos-para-muitos (N:N), pois:
#
# Um aluno pode se matricular em vários cursos.
# Um curso pode ter vários alunos.

# %% [markdown]
# 8. Considere as entidades do cenário anterior.
#
# Pergunta: Cite, pelo menos, três possíveis atributos
# que podem qualificar as entidades.

# %% [markdown]
# aluno:
# - id
# - nome
# - email
# - telefone
# - curso
#
# professor:
# - id
# - nome
# - email
# - telefone
# - especialidade
