# %% [markdown]
# # Lista de exercicios P1
# ## Lista 1: Exercícios de variáveis
# As variáveis são os blocos fundamentais de qualquer programa. Elas armazenam
# informações que você vai usar e manipular ao longo do código.
# Pense em uma variável como uma caixa etiquetada onde você guarda informações.
# O nome da variável é a etiqueta, e o conteúdo é o valor que você armazenou.

# %% [markdown]
# ### Exercício 1:
#  Cálculo de Bônus de Vendas (RH/Vendas): uma empresa decidiu dar
# um bônus de 10% sobre o faturamento total para a equipe de vendas. Calcule o
# valor do bônus e o faturamento final da empresa após subtrair esse bônus.
# 1. Faturamento inicial: 50.000
# 2. Percentual de bônus: 0.10

# %%
#calculo de bonus

faturamento = 50000
bonus = 0.1

faturamento_bonus = faturamento * bonus
valor_bonus = faturamento + faturamento_bonus

print(f"O faturamento com bonus é: {faturamento_bonus}")
print(f"O valor total com bonus é: {valor_bonus}")
# Out:
# O faturamento com bonus é: 5000.0
# O valor total com bonus é: 55000.0

# %% [markdown]
# ### Exercício 2:
#  Controle de Estoque de E-commerce (Logística): um e-commerce
# começou o dia com 250 unidades de um smartphone no estoque. Durante o dia,
# foram vendidas 78 unidades e chegaram mais 100 unidades de um fornecedor.
# Atualize a variável de estoque e exiba o saldo final.

# %%
estoque_inicial = 250
vendas = 78
entradas = 100

estoque_final = estoque_inicial - vendas + entradas

print(f"Saldo final do estoque: {estoque_final} unidades")
# Out:
# Saldo final do estoque: 272 unidades

# %% [markdown]
# ### Exercício 3:
#  Divisão de Cargas (Logística/Transporte): uma transportadora precisa levar 1.250 caixas em caminhões pequenos. Cada caminhão suporta exatamente 12 caixas. Quantos caminhões sairão totalmente cheios? (Use //) e quantas caixas sobrarão para serem enviadas em uma última viagem menor? (Use %).

# %%
caixas = 1250
capacidade_caminhao = 12

caminhoes_cheios = caixas // capacidade_caminhao
caixas_sobrando = caixas % capacidade_caminhao

print(f"Caminhões totalmente cheios: {caminhoes_cheios}")
print(f"Caixas para a última viagem: {caixas_sobrando}")
# Out:
# Caminhões totalmente cheios: 104
# Caixas para a última viagem: 2

# %% [markdown]
# ### Exercício 4:
#  Análise de Margem de Lucro (Financeiro): uma consultoria faturou R$ 15.000,00 em um projeto. Os custos fixos foram de R$ 5.000,00 e o imposto sobre o faturamento é de 15%. Calcule o imposto, o lucro líquido e a margem de lucro (Lucro / Faturamento). No final, crie uma variável booleana chamada meta_atingida que verifica se a margem de lucro é superior a 0.30 (30%).

# %%
faturamento = 15000
custos_fixos = 5000
aliquota_imposto = 0.15

imposto = faturamento * aliquota_imposto
lucro_liquido = faturamento - custos_fixos - imposto
margem_lucro = lucro_liquido / faturamento
meta_atingida = margem_lucro > 0.30

print(f"Imposto: R$ {imposto:.2f}")
print(f"Lucro líquido: R$ {lucro_liquido:.2f}")
print(f"Margem de lucro: {margem_lucro:.2%}")
print(f"Meta atingida: {meta_atingida}")
# Out:
# Imposto: R$ 2250.00
# Lucro líquido: R$ 7750.00
# Margem de lucro: 51.67%
# Meta atingida: True

# %% [markdown]
# ### Exercício 5:
#  Conversão de Tempo de Contrato (Gestão de Projetos): um contrato de manutenção de software tem a duração de 40 meses. O cliente quer ver esse tempo no formato: “X anos e Y meses”. Utilize os operadores de divisão inteira e resto da divisão para converter os 40 meses.

# %%
meses_contrato = 40

anos = meses_contrato // 12
meses_restantes = meses_contrato % 12

print(f"Duração do contrato: {anos} anos e {meses_restantes} meses")
# Out:
# Duração do contrato: 3 anos e 4 meses

# %% [markdown]
# ## Lista 2: Exercícios de strings ##
# Manipular textos é uma das tarefas mais comuns na programação. Desde padronizar nomes em um banco de dados até gerar mensagens personalizadas, você precisa dominar strings.

# %% [markdown]
# ### Exercício 1:
# Relatório de Margem de Lucro (Setor Financeiro): uma empresa de varejo precisa de um resumo rápido sobre a performance de um produto. Dado o faturamento de R$ 45.000,00 e o custo de R$ 23.500,00, crie um programa que calcule o lucro e a margem de lucro (lucro dividido pelo faturamento). Exiba uma mensagem formatada onde o lucro use o separador de milhar e duas casas decimais, e a margem seja exibida como uma porcentagem inteira.

# %%
faturamento = 45000
custo = 23500

lucro = faturamento - custo
margem_lucro = lucro / faturamento

print(f"Lucro: R$ {lucro:,.2f}")
print(f"Margem de lucro: {margem_lucro:.0%}")
# Out:
# Lucro: R$ 21,500.00
# Margem de lucro: 48%

# %% [markdown]
# ### Exercício 2:
# Padronização de Dados de CRM (Setor de Vendas): um vendedor cadastrou um cliente com os dados desorganizados no sistema: nome = ” mArCoS aNtOnIo rOcHa ” e email = ” MARCOS.ROCHA@GMAIL.COM “. Para evitar duplicidade e erros de envio, você deve:
# 1. Remover os espaços extras no início e fim das duas variáveis.
# 2. Deixar o nome apenas com as primeiras letras de cada palavra em maiúsculo (formato de nome próprio).
# 3. Deixar o e-mail todo em letras minúsculas. Exiba os resultados finais no console.

# %%
nome = " mArCoS aNtOnIo rOcHa ".strip().title()
email = " MARCOS.ROCHA@GMAIL.COM ".strip().lower()

print(f"Nome: {nome}")
print(f"E-mail: {email}")
# Out:
# Nome: Marcos Antonio Rocha
# E-mail: marcos.rocha@gmail.com

# %% [markdown]
# ### Exercício 3:
# Migração de Servidor de E-mail (Setor de TI): sua empresa mudou de nome e todos os funcionários que usavam o domínio @empresa.com.br agora devem usar o domínio @grupocorp.com. O e-mail do funcionário é andre_silva@empresa.com.br. Crie um código que substitua automaticamente o domínio antigo pelo novo e exiba o novo endereço de e-mail.

# %%
email_funcionario = "andre_silva@empresa.com.br"
novo_email = email_funcionario.replace("@empresa.com.br", "@grupocorp.com")

print(f"Novo endereço de e-mail: {novo_email}")
# Out:
# Novo endereço de e-mail: andre_silva@grupocorp.com

# %% [markdown]
# ### Exercício 4:
# Extração de Username para Log (Setor de Segurança): para criar um log de acessos, o sistema precisa extrair apenas a parte do nome do usuário de um e-mail corporativo (tudo o que vem antes do @). Dado o e-mail beatriz.oliveira@grupocorp.com, use a função .find() e o fatiamento de texto para extrair e exibir apenas o nome beatriz.oliveira.

# %%
email_usuario = "beatriz.oliveira@grupocorp.com"

posicao_arroba = email_usuario.find("@")
username = email_usuario[:posicao_arroba]

print(f"Username: {username}")
# Out:
# Username: beatriz.oliveira

# %% [markdown]
# ### Exercício 5:
# Personalização de E-mail de Marketing (Setor de Marketing): o marketing quer enviar um e-mail de boas-vindas. O cliente forneceu o nome completo: lucas ferreira souza. Você deve extrair apenas o primeiro nome para usar na saudação (ex: “Olá, Lucas!”). O código deve:
# 1. Encontrar a posição do primeiro espaço.
# 2. Fatiar o texto para pegar apenas o primeiro nome.
# 3. Formatar o nome com a primeira letra maiúscula.
# 4. Exibir a mensagem: “Olá, [Primeiro Nome], seja bem-vindo ao nosso clube!”

# %%
nome_completo = "lucas ferreira souza"

posicao_espaco = nome_completo.find(" ")
primeiro_nome = nome_completo[:posicao_espaco].capitalize()

print(f"Olá, {primeiro_nome}, seja bem-vindo(a) ao nosso clube!.")
# Out:
# Olá, Lucas, seja bem-vindo(a) ao nosso clube!.

# %% [markdown]
# ## Lista 3: Exercícios de inputs
# Programas que interagem com usuários precisam receber e validar informações. Os exercícios de input ensinam como captar dados e tratá-los adequadamente.

# %% [markdown]
# ### Exercício 1:
# Calculadora de Imposto sobre Vendas (Setor Fiscal): uma empresa de serviços precisa calcular o imposto de 15% sobre o valor bruto de uma nota fiscal. Como o valor muitas vezes vem copiado de planilhas com “R$” e vírgula, seu programa deve:
# 1. Pedir para o usuário digitar o valor bruto (Ex: R$ 5.000,00).
# 2. Limpar o texto removendo o “R$” e trocando a vírgula por ponto.
# 3. Converter para número decimal (float).
# 4. Calcular o valor do imposto (15% do valor bruto).
# 5. Exibir uma mensagem formatada com f-string mostrando o valor do imposto com duas casas decimais.

# %%
valor_bruto = input("Digite o valor bruto (ex.: R$ 5.000,00): ")

valor_bruto = valor_bruto.replace("R$", "").replace(".", "").replace(",", ".").strip()
valor_bruto = float(valor_bruto)

imposto = valor_bruto * aliquota_imposto

print(f"Valor do imposto: R$ {imposto:.2f}")
# Out:
# Valor do imposto: R$ 750.00

# %% [markdown]
# ### Exercício 3:
# Análise de Metas de Vendas (Setor Comercial): um gerente quer comparar o desempenho de duas filiais. O programa deve:
# 1. Pedir o faturamento da Loja A e o faturamento da Loja B (o usuário pode digitar números decimais).
# 2. Calcular o faturamento total das duas lojas.
# 3. Calcular a média de faturamento entre elas.
# 4. Exibir uma única mensagem formatada informando o total e a média, utilizando o separador de milhar e duas casas decimais.

# %%
faturamento_a = float(input("Digite o faturamento da Loja A: "))
faturamento_b = float(input("Digite o faturamento da Loja B: "))

faturamento_total = faturamento_a + faturamento_b
media_faturamento = faturamento_total / 2

print(f"Faturamento total: R$ {faturamento_total:.2f}")
print(f"Média do faturamento: R$ {media_faturamento:.2f}")
# Out:
# Faturamento total: R$ 14000.00
# Média do faturamento: R$ 7000.00

# %% [markdown]
# ## Lista 4: Exercícios com if
# Estruturas condicionais permitem que seu programa tome decisões baseadas em diferentes situações. São essenciais para criar lógica de negócio.

# %% [markdown]
# ### Exercício 1:
# Validação de Investimento (Setor Financeiro): uma corretora de valores quer automatizar a recomendação básica de perfil. Crie um programa que peça ao usuário o valor que ele deseja investir.
# 1. Se o valor for menor que R$ 1.000,00, exiba: “Perfil iniciante: Sugerimos Tesouro Direto”.
# 2. Se o valor for entre R$ 1.000,00 e R$ 5.000,00 (inclusive), exiba: “Perfil moderado: Sugerimos Fundos Imobiliários”.
# 3. Se o valor for acima de R$ 5.000,00, exiba: “Perfil arrojado: Sugerimos Ações”. Lembre-se de tratar o input caso o usuário digite “R$” ou use vírgula.

# %%
valor_investimento = float(input("Digite o valor do investimento: "))

if valor_investimento <= 1000:
    print("Perfil conservador: Sugerimos Tesouro Direto");

if valor_investimento > 1000 and valor_investimento < 5000:
    print("Perfil moderado: Sugerimos Fundos Imobiliarios")

if valor_investimento >= 5000:
    print("Perfil agressivo: Sugerimos Ações")
# Out:
# Perfil agressivo: Sugerimos Ações

# %% [markdown]
# ### Exercício 2:
# Controle de Acesso ao Sistema (Setor de Segurança): você tem uma lista de e-mails de administradores: admins =[“ana@empresa.com”,”guilherme@empresa.com”, “felipe@empresa.com”].
# Crie um programa que peça o e-mail do usuário. O programa deve:
# 1. Padronizar o e-mail (letras minúsculas e sem espaços).
# 2. Verificar se o e-mail está na lista de admins.
# 3. Se estiver, exibir: “Acesso liberado! Bem-vindo ao painel de controle”.
# 4. Caso contrário, exibir: “Acesso negado. Você não tem permissões de administrador”.

# %%
admins = ["ana@empresa.com", "guilherme@empresa.com", "felipe@empresa.com"]

email_usuario = input("Digite seu e-mail: ").strip().lower()

if email_usuario in admins:
    print("Acesso liberado! Bem-vindo ao painel de controle")
else:
    print("Acesso negado. Você não tem permissões de administrador")
# Out:
# Acesso negado. Você não tem permissões de administrador

# %% [markdown]
# ### Exercício 3:
# Cálculo de Desconto Progressivo (Setor de Vendas): um ecommerce aplica descontos automáticos no carrinho. Crie um programa que receba o valor total da compra e aplique a seguinte lógica:
# 1. Compras a partir de R$ 500,00: 15% de desconto.
# 2. Compras a partir de R$ 200,00 (e menos de 500): 10% de desconto.
# 3. Compras abaixo de R$ 200,00: Sem desconto. O programa deve exibir o valor do desconto e o valor final a pagar, formatados em R$.

# %%
valor_compra = float(input("Digite o valor da compra: "))

if valor_compra >= 500:
    valor_desconto = valor_compra * 0.15
elif valor_compra > 200 and valor_compra < 500:
    valor_desconto = valor_compra * 0.10
else:
    valor_desconto = 0

print(f"Valor do desconto: R$ {valor_desconto:.2f}")
print(f"Valor final da compra: R$ {valor_compra - valor_desconto:.2f}")
# Out:
# Valor do desconto: R$ 0.00
# Valor final da compra: R$ 20.00

# %% [markdown]
# ### Exercício 4:
# Análise de Metas Combinadas (Setor Comercial): uma empresa paga bônus se a meta individual do vendedor e a meta da loja forem batidas.
# 1. Peça as vendas do vendedor e a meta individual dele.
# 2. Peça as vendas totais da loja e a meta da loja.
# 3. Se o vendedor bater a meta dele E a loja bater a meta total, o bônus é de 20% sobre as vendas do vendedor.
# 4. Caso contrário, o bônus é zero. Exiba a mensagem: “Seu bônus este mês é de: R$[valor]”.

# %%
vendas_vendedor = float(input("Digite o valor das vendas do vendedor A: "))
meta_venda = float(input("Digite a meta de vendas do vendedor A: "))
venda_loja = float(input("Digite o valor total de vendas da loja: "))
meta_loja = float(input("Digite a meta de vendas da loja: "))

if vendas_vendedor >= meta_venda and venda_loja >= meta_loja:
    bonus_vendedor_a = vendas_vendedor * 0.20
else:
    bonus_vendedor_a = 0

print(f"Valor do bônus do vendedor A: R$ {bonus_vendedor_a:.2f}")
print(f"Valor total de vendas da loja: R$ {venda_loja:.2f}")
# Out:
# Valor do bônus do vendedor A: R$ 0.00
# Valor total de vendas da loja: R$ 1000.00

# %% [markdown]
# ### Exercício 5:
# Sistema de Triagem de E-mails (Setor de Customer Experience): crie um sistema que ajude a filtrar para qual departamento uma reclamação deve ir.
# O usuário deve digitar o assunto do e-mail.
# 1. Se no assunto aparecer a palavra “pagamento” ou “boleto”, exiba: “Encaminhado para o Financeiro”.
# 2. Se no assunto aparecer a palavra “entrega” ou “atraso”, exiba: “Encaminhado para a Logística”.
# 3. Caso não seja nenhum desses, exiba: “Encaminhado para o Suporte Geral”. Dica: Use o operador in para verificar se a palavra está dentro do texto.

# %%
assunto_email = input("Digite o assunto do e-mail: ").strip().lower()

if "pagamento" in assunto_email or "boleto" in assunto_email:
    print("encaminhado para o setor financeiro", f"Assunto do e-mail: {assunto_email}")
elif "entrega" in assunto_email or "atraso" in assunto_email:
    print("encaminhado para o setor de logística", f"Assunto do e-mail: {assunto_email}")
else:
    print("encaminhado para o Suporte Geral", f"Assunto do e-mail: {assunto_email}")
# Out:
# encaminhado para o setor financeiro Assunto do e-mail: boleto
